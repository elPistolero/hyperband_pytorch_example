# %% [markdown]
# # A short example on using hyperopt/hyperband with pytorch
#
# The hyperband algorithm randomly generates a set of configurations of hyperparameters and then tests them with some model on a given dataset. Initially, the tests are computed using very few iterations. The best performing 50% of the configurations are kept and the other 50% are resampled from the space of hyperparameters (successive halving).
#
# In further steps the number of generated configurations is reduced and the number of iterations to evaluate their performance is increased. This is repeated until only one configuration remains. Please see this [post](https://people.eecs.berkeley.edu/~kjamieson/hyperband.html) with a link to the paper for more details.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.nn.init as init
from torch.autograd import Variable
from torchvision.datasets import MNIST
from torchvision import transforms
from hyperopt import hp
from hyperopt.pyll.stochastic import sample
import pickle

# %% [markdown]
# The following code for the hyperband algorithm is adapted from [here](https://github.com/zygmuntz/hyperband). I slightly modified it to support python 3.

# %%
from __future__ import print_function

import numpy as np

from random import random
from math import log, ceil
from time import time, ctime



class Hyperband:
    
    def __init__( self, get_params_function, try_params_function ):
        self.get_params = get_params_function
        self.try_params = try_params_function
        
        self.max_iter = 81      # maximum iterations per configuration
        self.eta = 3            # defines configuration downsampling rate (default = 3)

        self.logeta = lambda x: log( x ) / log( self.eta )
        self.s_max = int( self.logeta( self.max_iter ))
        self.B = ( self.s_max + 1 ) * self.max_iter

        self.results = []    # list of dicts
        self.counter = 0
        self.best_loss = np.inf
        self.best_counter = -1
        

    # can be called multiple times
    def run( self, skip_last = 0, dry_run = False ):
        
        for s in reversed( range( self.s_max + 1 )):
            
            # initial number of configurations
            n = int( ceil( self.B / self.max_iter / ( s + 1 ) * self.eta ** s ))    
            
            # initial number of iterations per config
            r = self.max_iter * self.eta ** ( -s )        

            # n random configurations
            T = [ self.get_params() for i in range( n )] 
            
            for i in range(( s + 1 ) - int( skip_last )):    # changed from s + 1
                
                # Run each of the n configs for <iterations> 
                # and keep best (n_configs / eta) configurations
                
                n_configs = n * self.eta ** ( -i )
                n_iterations = r * self.eta ** ( i )
                
                print("\n*** {} configurations x {:.1f} iterations each".format( n_configs, n_iterations ))
                
                val_losses = []
                early_stops = []
                
                for t in T:
                    
                    self.counter += 1
                    print("\n{} | {} | lowest loss so far: {:.4f} (run {})\n".format( self.counter, ctime(), self.best_loss, self.best_counter ))
                    
                    start_time = time()
                    
                    if dry_run:
                        result = { 'loss': random(), 'log_loss': random(), 'auc': random()}
                    else:
                        result = self.try_params( n_iterations, t )        # <---
                        
                    assert( type( result ) == dict )
                    assert( 'loss' in result )
                    
                    seconds = int( round( time() - start_time ))
                    print("\n{} seconds.".format( seconds))
                    
                    loss = result['loss']    
                    val_losses.append( loss )
                    
                    early_stop = result.get( 'early_stop', False )
                    early_stops.append( early_stop )
                    
                    # keeping track of the best result so far (for display only)
                    # could do it be checking results each time, but hey
                    if loss < self.best_loss:
                        self.best_loss = loss
                        self.best_counter = self.counter
                    
                    result['counter'] = self.counter
                    result['seconds'] = seconds
                    result['params'] = t
                    result['iterations'] = n_iterations
                    
                    self.results.append( result )
                
                # select a number of best configurations for the next loop
                # filter out early stops, if any
                indices = np.argsort( val_losses )
                T = [ T[i] for i in indices if not early_stops[i]]
                T = T[ 0:int( n_configs / self.eta )]
        
        return self.results

# %% [markdown]
# ## The model
# Here I define a very simple model (based on the pytorch example for MNIST) that is constructed based on some hyperparameters (e.g. number of convolution filters, dropout or initialization scheme).

# %%
class Net(nn.Module):
    def __init__(self, dropout, conv1_n, conv2_n, fc_n, act_fn, init_fn):
        assert act_fn in ['relu', 'lrelu', 'elu']
        assert init_fn in ['xavier_uniform', 'xavier_normal', 'he_normal', 'he_uniform']
        
        super(Net, self).__init__()
        
        if act_fn == 'relu':
            self.act_fn = F.relu
            gain = init.calculate_gain('relu')
        elif act_fn == 'lrelu':
            self.act_fn = F.leaky_relu
            gain = init.calculate_gain('leaky_relu')
        else:
            self.act_fn = F.elu
            gain = init.calculate_gain('leaky_relu')
            
        if init_fn == 'xavier_uniform':
            init_layers = lambda tensor: init.xavier_uniform(tensor, gain=gain)
            init_last = lambda tensor: init.xavier_uniform(tensor, gain=1)
        elif init_fn == 'xavier_normal':
            init_layers = lambda tensor: init.xavier_normal(tensor, gain=gain)
            init_last = lambda tensor: init.xavier_normal(tensor, gain=1)
        elif init_fn == 'he_uniform':
            init_layers = init.kaiming_uniform
            init_last = init.kaiming_uniform
        else:
            init_layers = init.kaiming_normal
            init_last = init.kaiming_normal
        
        self.conv1 = nn.Conv2d(1, conv1_n, kernel_size=5, bias=False)
        init_layers(self.conv1.weight)
        self.conv2 = nn.Conv2d(conv1_n, conv2_n, kernel_size=5, bias=False)
        init_layers(self.conv2.weight)
        self.conv2_drop = nn.Dropout2d(p=dropout)
        self.dropout = dropout
        self.n_flat = 4*4*conv2_n
        self.fc1 = nn.Linear(self.n_flat, fc_n)
        init_layers(self.fc1.weight)
        self.fc2 = nn.Linear(fc_n, 10)
        init_last(self.fc2.weight)
        
    def forward(self, x):
        x = self.act_fn(F.max_pool2d(self.conv1(x), 2))
        x = self.act_fn(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, self.n_flat)
        x = self.act_fn(self.fc1(x))
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x)

# %% [markdown]
# ## The hyperparameter space
# First, we have to define the hyperparameter space, i.e. which hyperparameters are we interested in and how should they be sampled. I use [hyperopt](http://hyperopt.github.io/hyperopt/) to define the search space.

# %%
space = {
    'dropout': hp.quniform('dropout', 0, 0.5, 0.1),
    'batchsize': hp.choice('batchsize', (128, 256)),
    'fc_n': hp.choice('fc_n', (32, 64, 128)),
    'conv1_n': hp.choice('fc_n', (16, 32, 64)),
    'conv2_n': hp.choice('fc_n', (16, 32, 64)),
    'init_fn': hp.choice('init_fn', ('xavier_uniform', 'xavier_normal', 'he_normal', 'he_uniform')),
    'act_fn': hp.choice('act_fn', ('relu', 'lrelu', 'elu')),
    'lr': hp.loguniform('lr', -10, -2),
    'l2': hp.loguniform('l2', -10, -2),
}

# %% [markdown]
# The hyperband algorithm requires to functions (`get_params` and `try_params`).
# As the names imply, `get_params` simply returns  a configuration sampled from the hyperparameter (search) space.
# `try_params` takes a set of hyperparameters and then uses them to construct and train a model before returning the loss on the validation set. I used the test set for demonstration purposes.

# %%
def get_params():
    return sample(space)

# %%
def try_params(n_iterations, params):
    n_iterations = int(round(n_iterations))
    print("iterations: ", n_iterations)
    print("params: ", params)
    
    train_loader = torch.utils.data.DataLoader(MNIST('data', train=True, download=True, transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])), batch_size=params['batchsize'])
    test_loader = torch.utils.data.DataLoader(MNIST('data', train=False, download=True, transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])), batch_size=params['batchsize'])
    
    model = Net(params['dropout'], params['conv1_n'], params['conv2_n'], params['fc_n'], params['act_fn'], params['init_fn'])
    if torch.cuda.is_available():
        model.cuda()
    optimizer = optim.Adam(model.parameters(), lr=params['lr'], weight_decay=params['l2'])
    
    model.train()
    for epoch in range(n_iterations):
        for data, target in train_loader:
            if torch.cuda.is_available():
                data, target = data.cuda(), target.cuda()
            data, target = Variable(data), Variable(target)
            optimizer.zero_grad()
            loss = F.nll_loss(model(data), target)
            loss.backward()
            optimizer.step()
    
    model.eval()
    test_loss = 0
    correct = 0
    for data, target in test_loader:
        if torch.cuda.is_available():
            data, target = data.cuda(), target.cuda()
        data, target = Variable(data, volatile=True), Variable(target)
        output = model(data)
        test_loss += F.nll_loss(output, target, size_average=False).data[0]
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()

    test_loss /= len(test_loader.dataset)
    accuracy = 100. * correct / len(test_loader.dataset)
    
    return {'loss': test_loss, 'accuracy': accuracy}

# %% [markdown]
# ## Running hyperband
# We can now run our experiments in order to hopefully find a good configuration of hyperparameters.

# %%
hyperband = Hyperband(get_params, try_params)
results = hyperband.run()
# Out:
# *** 81 configurations x 1.0 iterations each
#
# 1 | Wed Oct  4 17:25:13 2017 | lowest loss so far: inf (run -1)
#
# iterations:  1
# params:  {'lr': 0.08355500484510042, 'conv1_n': 32, 'init_fn': 'xavier_uniform', 'fc_n': 128, 'dropout': 0.4, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.00018721158029257873, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 2 | Wed Oct  4 17:25:18 2017 | lowest loss so far: 1.4036 (run 1)
#
# iterations:  1
# params:  {'lr': 0.0004112842617591849, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 64, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.0002400717559614904, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 3 | Wed Oct  4 17:25:22 2017 | lowest loss so far: 0.0864 (run 2)
#
# iterations:  1
# params:  {'lr': 0.0008600033044224089, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 64, 'dropout': 0.2, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.00234224380412097, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 4 | Wed Oct  4 17:25:26 2017 | lowest loss so far: 0.0864 (run 2)
#
# iterations:  1
# params:  {'lr': 0.00013295418261345934, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 128, 'dropout': 0.4, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.0012508323635593362, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 5 | Wed Oct  4 17:25:30 2017 | lowest loss so far: 0.0864 (run 2)
#
# iterations:  1
# params:  {'lr': 7.49528374869873e-05, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.1, 'conv2_n': 16, 'batchsize': 128, 'l2': 6.110955095163964e-05, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 6 | Wed Oct  4 17:25:35 2017 | lowest loss so far: 0.0864 (run 2)
#
# iterations:  1
# params:  {'lr': 0.00015874624604714628, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 64, 'dropout': 0.5, 'conv2_n': 16, 'batchsize': 256, 'l2': 6.239206172291611e-05, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 7 | Wed Oct  4 17:25:39 2017 | lowest loss so far: 0.0864 (run 2)
#
# iterations:  1
# params:  {'lr': 4.860861195539705e-05, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.1, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.07752029124641166, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 8 | Wed Oct  4 17:25:43 2017 | lowest loss so far: 0.0864 (run 2)
#
# iterations:  1
# params:  {'lr': 0.0732602831555205, 'conv1_n': 16, 'init_fn': 'xavier_uniform', 'fc_n': 128, 'dropout': 0.1, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.0004363921531826153, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 9 | Wed Oct  4 17:25:47 2017 | lowest loss so far: 0.0864 (run 2)
#
# iterations:  1
# params:  {'lr': 0.015442757169363018, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 64, 'dropout': 0.4, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.0015155578052872605, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 10 | Wed Oct  4 17:25:51 2017 | lowest loss so far: 0.0864 (run 2)
#
# iterations:  1
# params:  {'lr': 6.464301676132385e-05, 'conv1_n': 32, 'init_fn': 'xavier_uniform', 'fc_n': 32, 'dropout': 0.4, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.0031548648990617737, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 11 | Wed Oct  4 17:25:55 2017 | lowest loss so far: 0.0864 (run 2)
#
# iterations:  1
# params:  {'lr': 0.061463393688216295, 'conv1_n': 16, 'init_fn': 'xavier_uniform', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.0070962355223682, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 12 | Wed Oct  4 17:25:59 2017 | lowest loss so far: 0.0864 (run 2)
#
# iterations:  1
# params:  {'lr': 0.013713344470870097, 'conv1_n': 32, 'init_fn': 'xavier_uniform', 'fc_n': 64, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.0020225177922327583, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 13 | Wed Oct  4 17:26:03 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.00012931665635861067, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.070417706460251, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 14 | Wed Oct  4 17:26:07 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.011751905930390317, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.30000000000000004, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.001788445991947289, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 15 | Wed Oct  4 17:26:12 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.002047889365695868, 'conv1_n': 64, 'init_fn': 'he_uniform', 'fc_n': 32, 'dropout': 0.2, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.05328397726959984, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 16 | Wed Oct  4 17:26:16 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.002266682612505664, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.5, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.006104780732462272, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 17 | Wed Oct  4 17:26:20 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.014001026692691739, 'conv1_n': 64, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.4, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.0037947821138274228, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 18 | Wed Oct  4 17:26:24 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.000188875797283059, 'conv1_n': 32, 'init_fn': 'he_normal', 'fc_n': 64, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.00011679478317264591, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 19 | Wed Oct  4 17:26:28 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.06003800319803185, 'conv1_n': 32, 'init_fn': 'he_uniform', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.0320937904564996, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 20 | Wed Oct  4 17:26:32 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.00477251791066333, 'conv1_n': 16, 'init_fn': 'xavier_uniform', 'fc_n': 64, 'dropout': 0.1, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.06317412958751051, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 21 | Wed Oct  4 17:26:36 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.015144525191801905, 'conv1_n': 32, 'init_fn': 'xavier_uniform', 'fc_n': 128, 'dropout': 0.4, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.001740516893316059, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 22 | Wed Oct  4 17:26:40 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.011503681677319145, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.0001749330648248374, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 23 | Wed Oct  4 17:26:45 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.0015285955577612632, 'conv1_n': 32, 'init_fn': 'he_uniform', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.017893454002531, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 24 | Wed Oct  4 17:26:49 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.002101283485915277, 'conv1_n': 32, 'init_fn': 'xavier_uniform', 'fc_n': 32, 'dropout': 0.4, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.016257613542533255, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 25 | Wed Oct  4 17:26:53 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.008858949996023569, 'conv1_n': 16, 'init_fn': 'he_uniform', 'fc_n': 128, 'dropout': 0.4, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.012692094925905475, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 26 | Wed Oct  4 17:26:57 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.00026972793445011325, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 64, 'dropout': 0.1, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.02574228326750885, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 27 | Wed Oct  4 17:27:01 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.007130037256434559, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 64, 'dropout': 0.30000000000000004, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.06959626673367175, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 28 | Wed Oct  4 17:27:05 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.012158249098639605, 'conv1_n': 32, 'init_fn': 'xavier_uniform', 'fc_n': 128, 'dropout': 0.30000000000000004, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.00035302637641133986, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 29 | Wed Oct  4 17:27:10 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.0005100869365300272, 'conv1_n': 16, 'init_fn': 'xavier_uniform', 'fc_n': 64, 'dropout': 0.5, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.0002618938157217166, 'act_fn': 'lrelu'}
# 4 seconds.
#
# 30 | Wed Oct  4 17:27:14 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.0007971812450578527, 'conv1_n': 64, 'init_fn': 'he_uniform', 'fc_n': 32, 'dropout': 0.4, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.0002679302922015169, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 31 | Wed Oct  4 17:27:18 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.1331963340992927, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 128, 'dropout': 0.1, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.041651811394610716, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 32 | Wed Oct  4 17:27:22 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.00017346293690085896, 'conv1_n': 32, 'init_fn': 'xavier_uniform', 'fc_n': 64, 'dropout': 0.2, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.002823612683110437, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 33 | Wed Oct  4 17:27:26 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.10541501955523469, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.002568031244062151, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 34 | Wed Oct  4 17:27:30 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.0014742284761571375, 'conv1_n': 32, 'init_fn': 'xavier_uniform', 'fc_n': 64, 'dropout': 0.4, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.09513784635121507, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 35 | Wed Oct  4 17:27:35 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.0063835970173425184, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 64, 'dropout': 0.5, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.13111338928121757, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 36 | Wed Oct  4 17:27:39 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.0013278193607813074, 'conv1_n': 32, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.4, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.00024153331338579306, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 37 | Wed Oct  4 17:27:43 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.0003119173588276834, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 32, 'dropout': 0.1, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.0011454609854996854, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 38 | Wed Oct  4 17:27:47 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.028625311073936833, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 64, 'dropout': 0.2, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.0067219188499176305, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 39 | Wed Oct  4 17:27:51 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.027884494028231403, 'conv1_n': 32, 'init_fn': 'he_uniform', 'fc_n': 64, 'dropout': 0.2, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.028298477115278185, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 40 | Wed Oct  4 17:27:55 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.007187470529657146, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.30000000000000004, 'conv2_n': 32, 'batchsize': 256, 'l2': 6.800702199449652e-05, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 41 | Wed Oct  4 17:27:59 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.00032188386276046937, 'conv1_n': 32, 'init_fn': 'he_normal', 'fc_n': 64, 'dropout': 0.2, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.023141175263878846, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 42 | Wed Oct  4 17:28:04 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.0010568810787017625, 'conv1_n': 32, 'init_fn': 'xavier_uniform', 'fc_n': 32, 'dropout': 0.5, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.0003481629810426849, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 43 | Wed Oct  4 17:28:08 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.002546565521290165, 'conv1_n': 64, 'init_fn': 'he_uniform', 'fc_n': 32, 'dropout': 0.4, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.00019420322312303122, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 44 | Wed Oct  4 17:28:12 2017 | lowest loss so far: 0.0757 (run 12)
#
# iterations:  1
# params:  {'lr': 0.003515161044420364, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.4, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.000892074453986174, 'act_fn': 'lrelu'}
#
# 5 seconds.
#
# 45 | Wed Oct  4 17:28:17 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.00030599368840705983, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 256, 'l2': 6.147400023396258e-05, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 46 | Wed Oct  4 17:28:21 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.09963130600565495, 'conv1_n': 64, 'init_fn': 'xavier_normal', 'fc_n': 64, 'dropout': 0.1, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.0013930508879659877, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 47 | Wed Oct  4 17:28:25 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 5.1995747751846986e-05, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 64, 'dropout': 0.0, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.0567416214493092, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 48 | Wed Oct  4 17:28:29 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.0031240669823087105, 'conv1_n': 32, 'init_fn': 'xavier_uniform', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.0368213537190345, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 49 | Wed Oct  4 17:28:33 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.006608689407656125, 'conv1_n': 64, 'init_fn': 'he_uniform', 'fc_n': 64, 'dropout': 0.4, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.00028538116409237567, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 50 | Wed Oct  4 17:28:37 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.007714403851363535, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.006816163281281469, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 51 | Wed Oct  4 17:28:41 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.0002300591925480189, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 64, 'dropout': 0.0, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.00010671696692189356, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 52 | Wed Oct  4 17:28:45 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.07324663501034566, 'conv1_n': 32, 'init_fn': 'he_uniform', 'fc_n': 32, 'dropout': 0.4, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.00010107350324941924, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 53 | Wed Oct  4 17:28:49 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.02938995515752247, 'conv1_n': 16, 'init_fn': 'he_uniform', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 64, 'batchsize': 128, 'l2': 5.060071528733114e-05, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 54 | Wed Oct  4 17:28:54 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.013803360405355977, 'conv1_n': 64, 'init_fn': 'he_uniform', 'fc_n': 64, 'dropout': 0.4, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.08456293358277836, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 55 | Wed Oct  4 17:28:58 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.00015602450483819408, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.30000000000000004, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.0008787024728896199, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 56 | Wed Oct  4 17:29:02 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.001101731660168928, 'conv1_n': 64, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.5, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.011588745543306637, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 57 | Wed Oct  4 17:29:07 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 7.774360794685511e-05, 'conv1_n': 64, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.4, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.04909286375689136, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 58 | Wed Oct  4 17:29:11 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.00546440555967733, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.003625425637210741, 'act_fn': 'relu'}
# 4 seconds.
#
# 59 | Wed Oct  4 17:29:15 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.07176505431643829, 'conv1_n': 32, 'init_fn': 'he_uniform', 'fc_n': 128, 'dropout': 0.0, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.00028672526970305095, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 60 | Wed Oct  4 17:29:19 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.06413748603338029, 'conv1_n': 16, 'init_fn': 'xavier_uniform', 'fc_n': 64, 'dropout': 0.4, 'conv2_n': 16, 'batchsize': 128, 'l2': 9.719298663485391e-05, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 61 | Wed Oct  4 17:29:23 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.01319580553118669, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.0008840899621622176, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 62 | Wed Oct  4 17:29:27 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.09674697721880274, 'conv1_n': 32, 'init_fn': 'he_normal', 'fc_n': 64, 'dropout': 0.2, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.00015853047557018847, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 63 | Wed Oct  4 17:29:32 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.11198847669336111, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.4, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.12422836025686047, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 64 | Wed Oct  4 17:29:36 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.00020497582582767473, 'conv1_n': 64, 'init_fn': 'he_uniform', 'fc_n': 128, 'dropout': 0.1, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.003227028258909964, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 65 | Wed Oct  4 17:29:40 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.024729784432100006, 'conv1_n': 32, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.4, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.026969272881868282, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 66 | Wed Oct  4 17:29:44 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.0007564826399859771, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 64, 'dropout': 0.2, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.002319816980663235, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 67 | Wed Oct  4 17:29:48 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.11208134508399535, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 64, 'dropout': 0.2, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.0005035094253516996, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 68 | Wed Oct  4 17:29:53 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 5.11440525155616e-05, 'conv1_n': 32, 'init_fn': 'he_normal', 'fc_n': 32, 'dropout': 0.4, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.029845885765405995, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 69 | Wed Oct  4 17:29:57 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.06511160714729895, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 32, 'dropout': 0.1, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.00024670779902124563, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 70 | Wed Oct  4 17:30:00 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.0028134758638692697, 'conv1_n': 16, 'init_fn': 'he_uniform', 'fc_n': 64, 'dropout': 0.0, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.10968883594625066, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 71 | Wed Oct  4 17:30:05 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.006385917966012327, 'conv1_n': 16, 'init_fn': 'xavier_uniform', 'fc_n': 32, 'dropout': 0.1, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.00018032949989126503, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 72 | Wed Oct  4 17:30:09 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.005397260693884731, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 64, 'dropout': 0.1, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.0024428070496223804, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 73 | Wed Oct  4 17:30:13 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.0026456050401734627, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.1, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.019524399885899872, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 74 | Wed Oct  4 17:30:18 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.0017952947785108524, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 64, 'dropout': 0.0, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.0010350273219564311, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 75 | Wed Oct  4 17:30:22 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.019974496922455485, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.00016559005739516034, 'act_fn': 'elu'}
#
# 4 seconds.
#
# 76 | Wed Oct  4 17:30:26 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.01034764149541634, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.00016832489221715, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 77 | Wed Oct  4 17:30:30 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.010986604578004861, 'conv1_n': 32, 'init_fn': 'he_uniform', 'fc_n': 64, 'dropout': 0.30000000000000004, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.0014777152946604368, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 78 | Wed Oct  4 17:30:34 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.0022856872049355644, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.00460221344755316, 'act_fn': 'lrelu'}
#
# 4 seconds.
#
# 79 | Wed Oct  4 17:30:39 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.00784896864923675, 'conv1_n': 32, 'init_fn': 'xavier_uniform', 'fc_n': 64, 'dropout': 0.4, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.008361490711535668, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 80 | Wed Oct  4 17:30:43 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 4.874884570982469e-05, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 32, 'dropout': 0.0, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.014114403593666867, 'act_fn': 'relu'}
#
# 4 seconds.
#
# 81 | Wed Oct  4 17:30:47 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  1
# params:  {'lr': 0.005874787396511647, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 32, 'dropout': 0.5, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.0349914295551829, 'act_fn': 'relu'}
#
# 4 seconds.
#
# *** 27.0 configurations x 3.0 iterations each
#
# 82 | Wed Oct  4 17:30:51 2017 | lowest loss so far: 0.0685 (run 44)
#
# iterations:  3
# params:  {'lr': 0.003515161044420364, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.4, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.000892074453986174, 'act_fn': 'lrelu'}
#
# 12 seconds.
#
# 83 | Wed Oct  4 17:31:03 2017 | lowest loss so far: 0.0481 (run 82)
#
# iterations:  3
# params:  {'lr': 0.0022856872049355644, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.00460221344755316, 'act_fn': 'lrelu'}
#
# 12 seconds.
#
# 84 | Wed Oct  4 17:31:15 2017 | lowest loss so far: 0.0481 (run 82)
#
# iterations:  3
# params:  {'lr': 0.006385917966012327, 'conv1_n': 16, 'init_fn': 'xavier_uniform', 'fc_n': 32, 'dropout': 0.1, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.00018032949989126503, 'act_fn': 'elu'}
#
# 11 seconds.
#
# 85 | Wed Oct  4 17:31:26 2017 | lowest loss so far: 0.0481 (run 82)
#
# iterations:  3
# params:  {'lr': 0.013713344470870097, 'conv1_n': 32, 'init_fn': 'xavier_uniform', 'fc_n': 64, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.0020225177922327583, 'act_fn': 'elu'}
#
# 11 seconds.
#
# 86 | Wed Oct  4 17:31:36 2017 | lowest loss so far: 0.0481 (run 82)
#
# iterations:  3
# params:  {'lr': 0.005397260693884731, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 64, 'dropout': 0.1, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.0024428070496223804, 'act_fn': 'lrelu'}
#
# 12 seconds.
#
# 87 | Wed Oct  4 17:31:48 2017 | lowest loss so far: 0.0481 (run 82)
#
# iterations:  3
# params:  {'lr': 0.01319580553118669, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.0008840899621622176, 'act_fn': 'elu'}
# 11 seconds.
#
# 88 | Wed Oct  4 17:31:59 2017 | lowest loss so far: 0.0481 (run 82)
#
# iterations:  3
# params:  {'lr': 0.0013278193607813074, 'conv1_n': 32, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.4, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.00024153331338579306, 'act_fn': 'elu'}
#
# 11 seconds.
#
# 89 | Wed Oct  4 17:32:09 2017 | lowest loss so far: 0.0411 (run 88)
#
# iterations:  3
# params:  {'lr': 0.01034764149541634, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.00016832489221715, 'act_fn': 'relu'}
#
# 11 seconds.
#
# 90 | Wed Oct  4 17:32:20 2017 | lowest loss so far: 0.0411 (run 88)
#
# iterations:  3
# params:  {'lr': 0.0004112842617591849, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 64, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.0002400717559614904, 'act_fn': 'lrelu'}
#
# 12 seconds.
#
# 91 | Wed Oct  4 17:32:32 2017 | lowest loss so far: 0.0406 (run 90)
#
# iterations:  3
# params:  {'lr': 0.0002300591925480189, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 64, 'dropout': 0.0, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.00010671696692189356, 'act_fn': 'elu'}
#
# 12 seconds.
#
# 92 | Wed Oct  4 17:32:44 2017 | lowest loss so far: 0.0406 (run 90)
#
# iterations:  3
# params:  {'lr': 0.011751905930390317, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.30000000000000004, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.001788445991947289, 'act_fn': 'elu'}
#
# 12 seconds.
#
# 93 | Wed Oct  4 17:32:55 2017 | lowest loss so far: 0.0406 (run 90)
#
# iterations:  3
# params:  {'lr': 0.0017952947785108524, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 64, 'dropout': 0.0, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.0010350273219564311, 'act_fn': 'relu'}
#
# 12 seconds.
#
# 94 | Wed Oct  4 17:33:07 2017 | lowest loss so far: 0.0393 (run 93)
#
# iterations:  3
# params:  {'lr': 0.001101731660168928, 'conv1_n': 64, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.5, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.011588745543306637, 'act_fn': 'lrelu'}
#
# 12 seconds.
#
# 95 | Wed Oct  4 17:33:19 2017 | lowest loss so far: 0.0393 (run 93)
#
# iterations:  3
# params:  {'lr': 0.006608689407656125, 'conv1_n': 64, 'init_fn': 'he_uniform', 'fc_n': 64, 'dropout': 0.4, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.00028538116409237567, 'act_fn': 'lrelu'}
#
# 11 seconds.
#
# 96 | Wed Oct  4 17:33:29 2017 | lowest loss so far: 0.0393 (run 93)
#
# iterations:  3
# params:  {'lr': 0.00026972793445011325, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 64, 'dropout': 0.1, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.02574228326750885, 'act_fn': 'lrelu'}
#
# 12 seconds.
#
# 97 | Wed Oct  4 17:33:41 2017 | lowest loss so far: 0.0393 (run 93)
#
# iterations:  3
# params:  {'lr': 0.011503681677319145, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.0001749330648248374, 'act_fn': 'elu'}
#
# 12 seconds.
#
# 98 | Wed Oct  4 17:33:53 2017 | lowest loss so far: 0.0393 (run 93)
#
# iterations:  3
# params:  {'lr': 0.007714403851363535, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.006816163281281469, 'act_fn': 'elu'}
#
# 11 seconds.
#
# 99 | Wed Oct  4 17:34:04 2017 | lowest loss so far: 0.0393 (run 93)
#
# iterations:  3
# params:  {'lr': 0.00020497582582767473, 'conv1_n': 64, 'init_fn': 'he_uniform', 'fc_n': 128, 'dropout': 0.1, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.003227028258909964, 'act_fn': 'relu'}
#
# 11 seconds.
#
# 100 | Wed Oct  4 17:34:15 2017 | lowest loss so far: 0.0393 (run 93)
#
# iterations:  3
# params:  {'lr': 0.015442757169363018, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 64, 'dropout': 0.4, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.0015155578052872605, 'act_fn': 'lrelu'}
#
# 11 seconds.
#
# 101 | Wed Oct  4 17:34:25 2017 | lowest loss so far: 0.0393 (run 93)
#
# iterations:  3
# params:  {'lr': 0.002546565521290165, 'conv1_n': 64, 'init_fn': 'he_uniform', 'fc_n': 32, 'dropout': 0.4, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.00019420322312303122, 'act_fn': 'elu'}
#
# 11 seconds.
#
# 102 | Wed Oct  4 17:34:36 2017 | lowest loss so far: 0.0393 (run 93)
#
# iterations:  3
# params:  {'lr': 0.002101283485915277, 'conv1_n': 32, 'init_fn': 'xavier_uniform', 'fc_n': 32, 'dropout': 0.4, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.016257613542533255, 'act_fn': 'lrelu'}
#
# 11 seconds.
#
# 103 | Wed Oct  4 17:34:47 2017 | lowest loss so far: 0.0393 (run 93)
#
# iterations:  3
# params:  {'lr': 0.002266682612505664, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.5, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.006104780732462272, 'act_fn': 'relu'}
#
# 11 seconds.
#
# 104 | Wed Oct  4 17:34:57 2017 | lowest loss so far: 0.0393 (run 93)
#
# iterations:  3
# params:  {'lr': 0.0015285955577612632, 'conv1_n': 32, 'init_fn': 'he_uniform', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.017893454002531, 'act_fn': 'lrelu'}
#
# 12 seconds.
#
# 105 | Wed Oct  4 17:35:09 2017 | lowest loss so far: 0.0393 (run 93)
#
# iterations:  3
# params:  {'lr': 0.007187470529657146, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.30000000000000004, 'conv2_n': 32, 'batchsize': 256, 'l2': 6.800702199449652e-05, 'act_fn': 'lrelu'}
#
# 11 seconds.
#
# 106 | Wed Oct  4 17:35:20 2017 | lowest loss so far: 0.0393 (run 93)
#
# iterations:  3
# params:  {'lr': 0.00030599368840705983, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 256, 'l2': 6.147400023396258e-05, 'act_fn': 'lrelu'}
#
# 11 seconds.
#
# 107 | Wed Oct  4 17:35:30 2017 | lowest loss so far: 0.0393 (run 93)
#
# iterations:  3
# params:  {'lr': 0.0007971812450578527, 'conv1_n': 64, 'init_fn': 'he_uniform', 'fc_n': 32, 'dropout': 0.4, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.0002679302922015169, 'act_fn': 'lrelu'}
#
# 12 seconds.
#
# 108 | Wed Oct  4 17:35:42 2017 | lowest loss so far: 0.0393 (run 93)
#
# iterations:  3
# params:  {'lr': 0.00032188386276046937, 'conv1_n': 32, 'init_fn': 'he_normal', 'fc_n': 64, 'dropout': 0.2, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.023141175263878846, 'act_fn': 'relu'}
#
# 12 seconds.
#
# *** 9.0 configurations x 9.0 iterations each
#
# 109 | Wed Oct  4 17:35:54 2017 | lowest loss so far: 0.0393 (run 93)
#
# iterations:  9
# params:  {'lr': 0.0017952947785108524, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 64, 'dropout': 0.0, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.0010350273219564311, 'act_fn': 'relu'}
#
# 34 seconds.
#
# 110 | Wed Oct  4 17:36:27 2017 | lowest loss so far: 0.0384 (run 109)
#
# iterations:  9
# params:  {'lr': 0.0004112842617591849, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 64, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.0002400717559614904, 'act_fn': 'lrelu'}
#
# 34 seconds.
#
# 111 | Wed Oct  4 17:37:02 2017 | lowest loss so far: 0.0276 (run 110)
#
# iterations:  9
# params:  {'lr': 0.0013278193607813074, 'conv1_n': 32, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.4, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.00024153331338579306, 'act_fn': 'elu'}
#
# 31 seconds.
#
# 112 | Wed Oct  4 17:37:32 2017 | lowest loss so far: 0.0276 (run 110)
#
# iterations:  9
# params:  {'lr': 0.003515161044420364, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.4, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.000892074453986174, 'act_fn': 'lrelu'}
#
# 34 seconds.
#
# 113 | Wed Oct  4 17:38:07 2017 | lowest loss so far: 0.0276 (run 110)
#
# iterations:  9
# params:  {'lr': 0.00030599368840705983, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 256, 'l2': 6.147400023396258e-05, 'act_fn': 'lrelu'}
#
# 31 seconds.
#
# 114 | Wed Oct  4 17:38:37 2017 | lowest loss so far: 0.0276 (run 110)
#
# iterations:  9
# params:  {'lr': 0.0022856872049355644, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.00460221344755316, 'act_fn': 'lrelu'}
#
# 34 seconds.
#
# 115 | Wed Oct  4 17:39:12 2017 | lowest loss so far: 0.0276 (run 110)
#
# iterations:  9
# params:  {'lr': 0.00020497582582767473, 'conv1_n': 64, 'init_fn': 'he_uniform', 'fc_n': 128, 'dropout': 0.1, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.003227028258909964, 'act_fn': 'relu'}
#
# 31 seconds.
#
# 116 | Wed Oct  4 17:39:42 2017 | lowest loss so far: 0.0276 (run 110)
#
# iterations:  9
# params:  {'lr': 0.0002300591925480189, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 64, 'dropout': 0.0, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.00010671696692189356, 'act_fn': 'elu'}
# 34 seconds.
#
# 117 | Wed Oct  4 17:40:16 2017 | lowest loss so far: 0.0276 (run 110)
#
# iterations:  9
# params:  {'lr': 0.002546565521290165, 'conv1_n': 64, 'init_fn': 'he_uniform', 'fc_n': 32, 'dropout': 0.4, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.00019420322312303122, 'act_fn': 'elu'}
#
# 31 seconds.
#
# *** 3.0 configurations x 27.0 iterations each
#
# 118 | Wed Oct  4 17:40:47 2017 | lowest loss so far: 0.0276 (run 110)
#
# iterations:  27
# params:  {'lr': 0.0004112842617591849, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 64, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.0002400717559614904, 'act_fn': 'lrelu'}
#
# 101 seconds.
#
# 119 | Wed Oct  4 17:42:27 2017 | lowest loss so far: 0.0256 (run 118)
#
# iterations:  27
# params:  {'lr': 0.0013278193607813074, 'conv1_n': 32, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.4, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.00024153331338579306, 'act_fn': 'elu'}
#
# 91 seconds.
#
# 120 | Wed Oct  4 17:43:58 2017 | lowest loss so far: 0.0256 (run 118)
#
# iterations:  27
# params:  {'lr': 0.00030599368840705983, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 256, 'l2': 6.147400023396258e-05, 'act_fn': 'lrelu'}
#
# 91 seconds.
#
# *** 1.0 configurations x 81.0 iterations each
#
# 121 | Wed Oct  4 17:45:29 2017 | lowest loss so far: 0.0250 (run 120)
#
# iterations:  81
# params:  {'lr': 0.00030599368840705983, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 256, 'l2': 6.147400023396258e-05, 'act_fn': 'lrelu'}
#
# 270 seconds.
#
# *** 34 configurations x 3.0 iterations each
#
# 122 | Wed Oct  4 17:49:59 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 5.852569427250429e-05, 'conv1_n': 64, 'init_fn': 'he_uniform', 'fc_n': 64, 'dropout': 0.5, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.020608272112670287, 'act_fn': 'lrelu'}
#
# 12 seconds.
#
# 123 | Wed Oct  4 17:50:11 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.00350653475371674, 'conv1_n': 64, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.2, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.0006220636479767992, 'act_fn': 'relu'}
#
# 11 seconds.
#
# 124 | Wed Oct  4 17:50:22 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.0011305203910307274, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.0017190203249547013, 'act_fn': 'elu'}
#
# 12 seconds.
#
# 125 | Wed Oct  4 17:50:33 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.0018429002760118034, 'conv1_n': 16, 'init_fn': 'he_uniform', 'fc_n': 128, 'dropout': 0.0, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.08255583463866571, 'act_fn': 'relu'}
#
# 10 seconds.
#
# 126 | Wed Oct  4 17:50:44 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.08284888205256857, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 64, 'dropout': 0.1, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.005247695202080149, 'act_fn': 'relu'}
#
# 11 seconds.
#
# 127 | Wed Oct  4 17:50:54 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.0008971802233633626, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.5, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.036555915975658874, 'act_fn': 'elu'}
#
# 12 seconds.
#
# 128 | Wed Oct  4 17:51:06 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.0010503203180795182, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.4, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.008865893432868246, 'act_fn': 'elu'}
#
# 10 seconds.
#
# 129 | Wed Oct  4 17:51:17 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.0006922441877534663, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.2, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.00010998701606467502, 'act_fn': 'relu'}
#
# 12 seconds.
#
# 130 | Wed Oct  4 17:51:28 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.036598556138455925, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 64, 'dropout': 0.4, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.0009275732810146484, 'act_fn': 'lrelu'}
#
# 11 seconds.
#
# 131 | Wed Oct  4 17:51:39 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.04196535591733611, 'conv1_n': 16, 'init_fn': 'he_uniform', 'fc_n': 64, 'dropout': 0.1, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.00027896827761362175, 'act_fn': 'elu'}
#
# 12 seconds.
#
# 132 | Wed Oct  4 17:51:51 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.01153486497238555, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 32, 'dropout': 0.5, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.0003065354905730837, 'act_fn': 'elu'}
#
# 11 seconds.
#
# 133 | Wed Oct  4 17:52:01 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.011141561972859093, 'conv1_n': 16, 'init_fn': 'he_uniform', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.053532048091224915, 'act_fn': 'relu'}
#
# 11 seconds.
#
# 134 | Wed Oct  4 17:52:12 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.016985136408383086, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.5, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.002385899344511953, 'act_fn': 'elu'}
#
# 12 seconds.
#
# 135 | Wed Oct  4 17:52:24 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.004807496442941433, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 32, 'dropout': 0.2, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.0001745010641618486, 'act_fn': 'relu'}
#
# 12 seconds.
#
# 136 | Wed Oct  4 17:52:35 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.0009494555768554802, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 32, 'dropout': 0.1, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.0003813063619432032, 'act_fn': 'lrelu'}
#
# 12 seconds.
#
# 137 | Wed Oct  4 17:52:47 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 5.0551177234846913e-05, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 64, 'dropout': 0.5, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.06388793095608437, 'act_fn': 'elu'}
#
# 12 seconds.
#
# 138 | Wed Oct  4 17:52:59 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.03460480942664176, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.0050005264388261125, 'act_fn': 'elu'}
#
# 11 seconds.
#
# 139 | Wed Oct  4 17:53:09 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.0035943268594264364, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.1, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.0009203560812222365, 'act_fn': 'lrelu'}
#
# 11 seconds.
#
# 140 | Wed Oct  4 17:53:20 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.006678711986399095, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 128, 'dropout': 0.5, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.008239658131960552, 'act_fn': 'lrelu'}
#
# 11 seconds.
#
# 141 | Wed Oct  4 17:53:30 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.0032212253768822046, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 128, 'dropout': 0.1, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.009806222704905823, 'act_fn': 'lrelu'}
#
# 11 seconds.
#
# 142 | Wed Oct  4 17:53:41 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.0001609458890545396, 'conv1_n': 32, 'init_fn': 'xavier_uniform', 'fc_n': 32, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.0014416957360816978, 'act_fn': 'lrelu'}
#
# 11 seconds.
#
# 143 | Wed Oct  4 17:53:52 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.001628860845206489, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.4, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.03381410205831072, 'act_fn': 'elu'}
#
# 11 seconds.
#
# 144 | Wed Oct  4 17:54:02 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.0008403719208361412, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 32, 'dropout': 0.2, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.024558546599682204, 'act_fn': 'lrelu'}
# 11 seconds.
#
# 145 | Wed Oct  4 17:54:13 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.0004130988965427741, 'conv1_n': 64, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.0, 'conv2_n': 16, 'batchsize': 128, 'l2': 7.115528328092609e-05, 'act_fn': 'relu'}
#
# 12 seconds.
#
# 146 | Wed Oct  4 17:54:25 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.11232905181221525, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.30000000000000004, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.016141870628517848, 'act_fn': 'elu'}
#
# 12 seconds.
#
# 147 | Wed Oct  4 17:54:36 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 4.577394798930015e-05, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.4, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.0023646627638231996, 'act_fn': 'relu'}
#
# 11 seconds.
#
# 148 | Wed Oct  4 17:54:47 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.005294164193323202, 'conv1_n': 32, 'init_fn': 'he_uniform', 'fc_n': 64, 'dropout': 0.4, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.004835250175171994, 'act_fn': 'relu'}
#
# 12 seconds.
#
# 149 | Wed Oct  4 17:54:59 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.04603390013090216, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.12795483214762862, 'act_fn': 'relu'}
#
# 12 seconds.
#
# 150 | Wed Oct  4 17:55:10 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.03057146000633713, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 64, 'dropout': 0.4, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.0011403826551620577, 'act_fn': 'elu'}
#
# 12 seconds.
#
# 151 | Wed Oct  4 17:55:22 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.00165274787712503, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.1, 'conv2_n': 16, 'batchsize': 128, 'l2': 4.5443918280381285e-05, 'act_fn': 'elu'}
#
# 12 seconds.
#
# 152 | Wed Oct  4 17:55:34 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.003712795389472459, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 128, 'dropout': 0.4, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.004057629316036213, 'act_fn': 'relu'}
#
# 12 seconds.
#
# 153 | Wed Oct  4 17:55:45 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.02652567222441638, 'conv1_n': 64, 'init_fn': 'he_uniform', 'fc_n': 32, 'dropout': 0.1, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.009112248059921927, 'act_fn': 'elu'}
#
# 11 seconds.
#
# 154 | Wed Oct  4 17:55:56 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.031772670645348354, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 64, 'dropout': 0.30000000000000004, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.004166112001996821, 'act_fn': 'relu'}
#
# 11 seconds.
#
# 155 | Wed Oct  4 17:56:07 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  3
# params:  {'lr': 0.008696841211319434, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.1, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.0013918549522684072, 'act_fn': 'relu'}
#
# 11 seconds.
#
# *** 11.333333333333332 configurations x 9.0 iterations each
#
# 156 | Wed Oct  4 17:56:17 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.0011305203910307274, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.0017190203249547013, 'act_fn': 'elu'}
#
# 35 seconds.
#
# 157 | Wed Oct  4 17:56:52 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.0006922441877534663, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.2, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.00010998701606467502, 'act_fn': 'relu'}
#
# 34 seconds.
#
# 158 | Wed Oct  4 17:57:26 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.0004130988965427741, 'conv1_n': 64, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.0, 'conv2_n': 16, 'batchsize': 128, 'l2': 7.115528328092609e-05, 'act_fn': 'relu'}
#
# 34 seconds.
#
# 159 | Wed Oct  4 17:58:00 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.00165274787712503, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.1, 'conv2_n': 16, 'batchsize': 128, 'l2': 4.5443918280381285e-05, 'act_fn': 'elu'}
#
# 34 seconds.
#
# 160 | Wed Oct  4 17:58:34 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.0009494555768554802, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 32, 'dropout': 0.1, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.0003813063619432032, 'act_fn': 'lrelu'}
#
# 34 seconds.
#
# 161 | Wed Oct  4 17:59:08 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.00350653475371674, 'conv1_n': 64, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.2, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.0006220636479767992, 'act_fn': 'relu'}
#
# 31 seconds.
#
# 162 | Wed Oct  4 17:59:39 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.0035943268594264364, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.1, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.0009203560812222365, 'act_fn': 'lrelu'}
#
# 31 seconds.
#
# 163 | Wed Oct  4 18:00:10 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.0010503203180795182, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.4, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.008865893432868246, 'act_fn': 'elu'}
#
# 31 seconds.
#
# 164 | Wed Oct  4 18:00:41 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.0032212253768822046, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 128, 'dropout': 0.1, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.009806222704905823, 'act_fn': 'lrelu'}
#
# 31 seconds.
#
# 165 | Wed Oct  4 18:01:12 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.0008403719208361412, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 32, 'dropout': 0.2, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.024558546599682204, 'act_fn': 'lrelu'}
#
# 31 seconds.
#
# 166 | Wed Oct  4 18:01:42 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.008696841211319434, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 128, 'dropout': 0.1, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.0013918549522684072, 'act_fn': 'relu'}
#
# 31 seconds.
#
# *** 3.7777777777777777 configurations x 27.0 iterations each
#
# 167 | Wed Oct  4 18:02:13 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  27
# params:  {'lr': 0.0006922441877534663, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.2, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.00010998701606467502, 'act_fn': 'relu'}
#
# 101 seconds.
#
# 168 | Wed Oct  4 18:03:54 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  27
# params:  {'lr': 0.0009494555768554802, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 32, 'dropout': 0.1, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.0003813063619432032, 'act_fn': 'lrelu'}
#
# 101 seconds.
#
# 169 | Wed Oct  4 18:05:35 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  27
# params:  {'lr': 0.00165274787712503, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.1, 'conv2_n': 16, 'batchsize': 128, 'l2': 4.5443918280381285e-05, 'act_fn': 'elu'}
#
# 102 seconds.
#
# *** 1.259259259259259 configurations x 81.0 iterations each
#
# 170 | Wed Oct  4 18:07:17 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  81
# params:  {'lr': 0.0009494555768554802, 'conv1_n': 64, 'init_fn': 'he_normal', 'fc_n': 32, 'dropout': 0.1, 'conv2_n': 32, 'batchsize': 128, 'l2': 0.0003813063619432032, 'act_fn': 'lrelu'}
#
# 304 seconds.
#
# *** 15 configurations x 9.0 iterations each
#
# 171 | Wed Oct  4 18:12:21 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 6.830843472470244e-05, 'conv1_n': 16, 'init_fn': 'xavier_uniform', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.043553028085614155, 'act_fn': 'lrelu'}
#
# 31 seconds.
#
# 172 | Wed Oct  4 18:12:52 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.0003028687084104627, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.0018175522970480264, 'act_fn': 'lrelu'}
# 34 seconds.
#
# 173 | Wed Oct  4 18:13:26 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.00016587687507210025, 'conv1_n': 32, 'init_fn': 'he_uniform', 'fc_n': 64, 'dropout': 0.4, 'conv2_n': 64, 'batchsize': 256, 'l2': 9.821919477548803e-05, 'act_fn': 'lrelu'}
#
# 31 seconds.
#
# 174 | Wed Oct  4 18:13:56 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 5.684008369849797e-05, 'conv1_n': 32, 'init_fn': 'he_normal', 'fc_n': 64, 'dropout': 0.1, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.01937548373008604, 'act_fn': 'relu'}
#
# 31 seconds.
#
# 175 | Wed Oct  4 18:14:27 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.007425477299592599, 'conv1_n': 64, 'init_fn': 'he_uniform', 'fc_n': 64, 'dropout': 0.4, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.00030136605782824806, 'act_fn': 'lrelu'}
#
# 31 seconds.
#
# 176 | Wed Oct  4 18:14:58 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.00012758721407422747, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.1, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.004563684476310203, 'act_fn': 'lrelu'}
#
# 34 seconds.
#
# 177 | Wed Oct  4 18:15:32 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.0013483440781834506, 'conv1_n': 16, 'init_fn': 'he_uniform', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.00040322734004501697, 'act_fn': 'lrelu'}
#
# 31 seconds.
#
# 178 | Wed Oct  4 18:16:02 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.07075057059789243, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 64, 'dropout': 0.4, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.008540920633367534, 'act_fn': 'elu'}
#
# 30 seconds.
#
# 179 | Wed Oct  4 18:16:33 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.0007118337833536086, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 64, 'dropout': 0.2, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.011573809157401352, 'act_fn': 'elu'}
#
# 34 seconds.
#
# 180 | Wed Oct  4 18:17:07 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.00018175885653807703, 'conv1_n': 64, 'init_fn': 'he_uniform', 'fc_n': 64, 'dropout': 0.30000000000000004, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.04229858190971403, 'act_fn': 'lrelu'}
#
# 34 seconds.
#
# 181 | Wed Oct  4 18:17:41 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.001879935031520798, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 64, 'dropout': 0.30000000000000004, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.09294033836743354, 'act_fn': 'elu'}
#
# 31 seconds.
#
# 182 | Wed Oct  4 18:18:11 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.00024182892383454454, 'conv1_n': 32, 'init_fn': 'he_uniform', 'fc_n': 128, 'dropout': 0.1, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.00046410433103323773, 'act_fn': 'relu'}
#
# 34 seconds.
#
# 183 | Wed Oct  4 18:18:45 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.00036470681567962385, 'conv1_n': 32, 'init_fn': 'he_normal', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.0688349834494099, 'act_fn': 'relu'}
#
# 31 seconds.
#
# 184 | Wed Oct  4 18:19:16 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.0058829537736585225, 'conv1_n': 32, 'init_fn': 'he_normal', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.0005035818137335933, 'act_fn': 'elu'}
#
# 31 seconds.
#
# 185 | Wed Oct  4 18:19:47 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  9
# params:  {'lr': 0.03331711707353193, 'conv1_n': 64, 'init_fn': 'he_uniform', 'fc_n': 64, 'dropout': 0.30000000000000004, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.001950020259570116, 'act_fn': 'relu'}
#
# 31 seconds.
#
# *** 5.0 configurations x 27.0 iterations each
#
# 186 | Wed Oct  4 18:20:18 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  27
# params:  {'lr': 0.00024182892383454454, 'conv1_n': 32, 'init_fn': 'he_uniform', 'fc_n': 128, 'dropout': 0.1, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.00046410433103323773, 'act_fn': 'relu'}
#
# 102 seconds.
#
# 187 | Wed Oct  4 18:22:00 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  27
# params:  {'lr': 0.0003028687084104627, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.0018175522970480264, 'act_fn': 'lrelu'}
#
# 102 seconds.
#
# 188 | Wed Oct  4 18:23:42 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  27
# params:  {'lr': 0.0013483440781834506, 'conv1_n': 16, 'init_fn': 'he_uniform', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.00040322734004501697, 'act_fn': 'lrelu'}
#
# 91 seconds.
#
# 189 | Wed Oct  4 18:25:13 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  27
# params:  {'lr': 0.0058829537736585225, 'conv1_n': 32, 'init_fn': 'he_normal', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 32, 'batchsize': 256, 'l2': 0.0005035818137335933, 'act_fn': 'elu'}
#
# 91 seconds.
#
# 190 | Wed Oct  4 18:26:44 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  27
# params:  {'lr': 0.00016587687507210025, 'conv1_n': 32, 'init_fn': 'he_uniform', 'fc_n': 64, 'dropout': 0.4, 'conv2_n': 64, 'batchsize': 256, 'l2': 9.821919477548803e-05, 'act_fn': 'lrelu'}
#
# 91 seconds.
#
# *** 1.6666666666666665 configurations x 81.0 iterations each
#
# 191 | Wed Oct  4 18:28:14 2017 | lowest loss so far: 0.0249 (run 121)
#
# iterations:  81
# params:  {'lr': 0.00016587687507210025, 'conv1_n': 32, 'init_fn': 'he_uniform', 'fc_n': 64, 'dropout': 0.4, 'conv2_n': 64, 'batchsize': 256, 'l2': 9.821919477548803e-05, 'act_fn': 'lrelu'}
#
# 270 seconds.
#
# *** 8 configurations x 27.0 iterations each
#
# 192 | Wed Oct  4 18:32:44 2017 | lowest loss so far: 0.0203 (run 191)
#
# iterations:  27
# params:  {'lr': 0.0008042245680506868, 'conv1_n': 16, 'init_fn': 'he_uniform', 'fc_n': 128, 'dropout': 0.30000000000000004, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.0005953039730324044, 'act_fn': 'lrelu'}
#
# 101 seconds.
#
# 193 | Wed Oct  4 18:34:25 2017 | lowest loss so far: 0.0203 (run 191)
#
# iterations:  27
# params:  {'lr': 0.029582650750717268, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 128, 'dropout': 0.4, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.0004178386715550973, 'act_fn': 'relu'}
#
# 101 seconds.
#
# 194 | Wed Oct  4 18:36:06 2017 | lowest loss so far: 0.0203 (run 191)
#
# iterations:  27
# params:  {'lr': 0.038508991054556775, 'conv1_n': 32, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.2, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.010019207783232214, 'act_fn': 'relu'}
#
# 102 seconds.
#
# 195 | Wed Oct  4 18:37:48 2017 | lowest loss so far: 0.0203 (run 191)
#
# iterations:  27
# params:  {'lr': 0.0278456180023274, 'conv1_n': 32, 'init_fn': 'he_uniform', 'fc_n': 64, 'dropout': 0.0, 'conv2_n': 64, 'batchsize': 128, 'l2': 6.199936765026345e-05, 'act_fn': 'relu'}
#
# 100 seconds.
#
# 196 | Wed Oct  4 18:39:29 2017 | lowest loss so far: 0.0203 (run 191)
#
# iterations:  27
# params:  {'lr': 0.005215494834695938, 'conv1_n': 64, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.1, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.00012785054663949893, 'act_fn': 'elu'}
#
# 102 seconds.
#
# 197 | Wed Oct  4 18:41:10 2017 | lowest loss so far: 0.0203 (run 191)
#
# iterations:  27
# params:  {'lr': 0.009240565450674901, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 128, 'dropout': 0.0, 'conv2_n': 64, 'batchsize': 256, 'l2': 6.038068104491895e-05, 'act_fn': 'relu'}
#
# 90 seconds.
#
# 198 | Wed Oct  4 18:42:40 2017 | lowest loss so far: 0.0203 (run 191)
#
# iterations:  27
# params:  {'lr': 0.0642155470815881, 'conv1_n': 16, 'init_fn': 'he_uniform', 'fc_n': 128, 'dropout': 0.1, 'conv2_n': 16, 'batchsize': 256, 'l2': 0.0008835521086139416, 'act_fn': 'elu'}
#
# 91 seconds.
#
# 199 | Wed Oct  4 18:44:12 2017 | lowest loss so far: 0.0203 (run 191)
#
# iterations:  27
# params:  {'lr': 0.011563471379394927, 'conv1_n': 32, 'init_fn': 'he_uniform', 'fc_n': 64, 'dropout': 0.30000000000000004, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.021371911184232123, 'act_fn': 'elu'}
#
# 101 seconds.
#
# *** 2.6666666666666665 configurations x 81.0 iterations each
#
# 200 | Wed Oct  4 18:45:53 2017 | lowest loss so far: 0.0203 (run 191)
#
# iterations:  81
# params:  {'lr': 0.0008042245680506868, 'conv1_n': 16, 'init_fn': 'he_uniform', 'fc_n': 128, 'dropout': 0.30000000000000004, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.0005953039730324044, 'act_fn': 'lrelu'}
# 303 seconds.
#
# 201 | Wed Oct  4 18:50:56 2017 | lowest loss so far: 0.0203 (run 191)
#
# iterations:  81
# params:  {'lr': 0.005215494834695938, 'conv1_n': 64, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.1, 'conv2_n': 64, 'batchsize': 128, 'l2': 0.00012785054663949893, 'act_fn': 'elu'}
#
# 304 seconds.
#
# *** 5 configurations x 81.0 iterations each
#
# 202 | Wed Oct  4 18:56:00 2017 | lowest loss so far: 0.0203 (run 191)
#
# iterations:  81
# params:  {'lr': 0.0006828671855591531, 'conv1_n': 16, 'init_fn': 'he_normal', 'fc_n': 64, 'dropout': 0.1, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.10146351901746466, 'act_fn': 'elu'}
#
# 305 seconds.
#
# 203 | Wed Oct  4 19:01:04 2017 | lowest loss so far: 0.0203 (run 191)
#
# iterations:  81
# params:  {'lr': 0.00043521122298378505, 'conv1_n': 16, 'init_fn': 'xavier_normal', 'fc_n': 32, 'dropout': 0.0, 'conv2_n': 16, 'batchsize': 128, 'l2': 9.825493085017422e-05, 'act_fn': 'elu'}
#
# 299 seconds.
#
# 204 | Wed Oct  4 19:06:04 2017 | lowest loss so far: 0.0203 (run 191)
#
# iterations:  81
# params:  {'lr': 0.04166774035143852, 'conv1_n': 64, 'init_fn': 'xavier_uniform', 'fc_n': 64, 'dropout': 0.1, 'conv2_n': 16, 'batchsize': 128, 'l2': 0.00015614580912807555, 'act_fn': 'lrelu'}
#
# 303 seconds.
#
# 205 | Wed Oct  4 19:11:06 2017 | lowest loss so far: 0.0203 (run 191)
#
# iterations:  81
# params:  {'lr': 0.0017497813328824217, 'conv1_n': 16, 'init_fn': 'he_uniform', 'fc_n': 64, 'dropout': 0.4, 'conv2_n': 64, 'batchsize': 256, 'l2': 0.0004254294301640527, 'act_fn': 'elu'}
#
# 271 seconds.
#
# 206 | Wed Oct  4 19:15:37 2017 | lowest loss so far: 0.0203 (run 191)
#
# iterations:  81
# params:  {'lr': 0.003819339315246313, 'conv1_n': 16, 'init_fn': 'he_uniform', 'fc_n': 32, 'dropout': 0.30000000000000004, 'conv2_n': 32, 'batchsize': 128, 'l2': 9.11836965241369e-05, 'act_fn': 'relu'}
#
# 304 seconds.

# %%
with open('results.pkl', 'wb') as f:
    pickle.dump(results, f)

# %% [markdown]
# As you can see we found a reasonable setting of hyperparameters for our model. If we wanted to further explore the hyperparameter space we could call `hyperband.run()` again.

# %%
sorted(results, key=lambda r: r['loss'])[:5]
# Out:
# [{'accuracy': 99.44,
#   'counter': 191,
#   'iterations': 81.0,
#   'loss': 0.02028474977016449,
#   'params': {'act_fn': 'lrelu',
#    'batchsize': 256,
#    'conv1_n': 32,
#    'conv2_n': 64,
#    'dropout': 0.4,
#    'fc_n': 64,
#    'init_fn': 'he_uniform',
#    'l2': 9.821919477548803e-05,
#    'lr': 0.00016587687507210025},
#   'seconds': 270},
#  {'accuracy': 99.28,
#   'counter': 192,
#   'iterations': 27.0,
#   'loss': 0.02320907483100891,
#   'params': {'act_fn': 'lrelu',
#    'batchsize': 128,
#    'conv1_n': 16,
#    'conv2_n': 16,
#    'dropout': 0.30000000000000004,
#    'fc_n': 128,
#    'init_fn': 'he_uniform',
#    'l2': 0.0005953039730324044,
#    'lr': 0.0008042245680506868},
#   'seconds': 101},
#  {'accuracy': 99.39,
#   'counter': 121,
#   'iterations': 81.0,
#   'loss': 0.024867862105369568,
#   'params': {'act_fn': 'lrelu',
#    'batchsize': 256,
#    'conv1_n': 16,
#    'conv2_n': 64,
#    'dropout': 0.2,
#    'fc_n': 128,
#    'init_fn': 'xavier_normal',
#    'l2': 6.147400023396258e-05,
#    'lr': 0.00030599368840705983},
#   'seconds': 270},
#  {'accuracy': 99.27,
#   'counter': 120,
#   'iterations': 27.0,
#   'loss': 0.025038497066497804,
#   'params': {'act_fn': 'lrelu',
#    'batchsize': 256,
#    'conv1_n': 16,
#    'conv2_n': 64,
#    'dropout': 0.2,
#    'fc_n': 128,
#    'init_fn': 'xavier_normal',
#    'l2': 6.147400023396258e-05,
#    'lr': 0.00030599368840705983},
#   'seconds': 91},
#  {'accuracy': 99.26,
#   'counter': 118,
#   'iterations': 27.0,
#   'loss': 0.025590432095527648,
#   'params': {'act_fn': 'lrelu',
#    'batchsize': 128,
#    'conv1_n': 16,
#    'conv2_n': 64,
#    'dropout': 0.2,
#    'fc_n': 64,
#    'init_fn': 'xavier_normal',
#    'l2': 0.0002400717559614904,
#    'lr': 0.0004112842617591849},
#   'seconds': 101}]
